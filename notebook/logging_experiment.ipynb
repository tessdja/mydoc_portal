# %%
print("all ok")
# Out:
# all ok

# %%
import logging
import os
from datetime import datetime

# %% [markdown]
# #### Below commands will create logs in logs directory of the form 08_20_2025_13_16_42.log

# %%
logs_dir=os.path.join(os.getcwd(),"logs")

# %%
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
LOG_FILE
# Out:
# '08_20_2025_14_42_55.log'

# %%
LOG_FILE_PATH=os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger=logging.getLogger("MyDocPortal")

# %%
logger.info("This is an info message")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import structlog
log=structlog.get_logger()

# %%
log.info("User uploaded a file", user_id=123, filename="report.pdf")
# Out:
# 2025-08-20 14:43:23 [info     ] User uploaded a file           filename=report.pdf user_id=123

# %%
log.error("Failed to process PDF", error="File not found", user_id=123)
# Out:
# 2025-08-20 14:43:34 [error    ] Failed to process PDF          error='File not found' user_id=123

# %%
class MyClass:
    def __init__(self, name):
        self.name = name
    
    def __str__(self):
        return f"MyClass object with name: {self.name}"
    
    def __repr__(self):
        return f"MyClass object with name: {self.name}"

# %%
obj=MyClass("sunny")
